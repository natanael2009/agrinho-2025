# %% [markdown]
# <a href="https://colab.research.google.com/github/natanael2009/agrinho-2025/blob/main/aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**aula 1** ⚾ ♈ ⏰

# %%
print("I competição de programação dá Start")
ano = "II"
print(f"{ano} competição de programação da start")
# Out:
# I competição de programação dá Start
# II competição de programação da start
